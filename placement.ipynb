# %% [markdown]
# <a href="https://colab.research.google.com/github/jazmansandhu/AI-ML/blob/main/placement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-655cc16f-2b6a-4c7b-b618-7be72901f1e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-655cc16f-2b6a-4c7b-b618-7be72901f1e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv('placement.csv')  # no need to give D:\... path
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
#steps
# 0. preprocesses + EDA + Feature selection
# 1. extract input and output cols
# 2. scale the values
# 3. train test split
# 4. train the model
# 5. evaluate the model/ model selection
# 6. deploy the model

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 83   7.5  130.0
# 73   4.9   61.0
# 37   8.1  149.0
# 64   7.0   64.0
# 12   5.4  139.0
# ..   ...    ...
# 5    7.1   48.0
# 99   6.2  113.0
# 18   4.0  100.0
# 9    5.1   66.0
# 80   4.9  196.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 83    1
# 73    0
# 37    1
# 64    1
# 12    0
#      ..
# 5     1
# 99    1
# 18    0
# 9     0
# 80    0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 21   7.1  151.0
# 89   4.9  151.0
# 66   6.9   96.0
# 15   5.1  176.0
# 95   4.3  200.0
# 67   5.0  118.0
# 29   7.0  112.0
# 40   4.9  134.0
# 0    6.8  123.0
# 28   5.2   90.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.29140006,  0.19146773],
#        [-0.97898021, -1.52428203],
#        [ 1.81533397,  0.66392056],
#        [ 0.85478847, -1.44968422],
#        [-0.54236862,  0.41526117],
#        [-0.19307935,  1.08664151],
#        [ 0.68014383, -0.80316981],
#        [-0.89165789, -1.47455016],
#        [ 0.68014383, -0.25611917],
#        [-0.89165789, -0.77830388],
#        [ 1.81533397,  1.08664151],
#        [ 0.33085456, -0.15665541],
#        [-0.01843471,  0.0422721 ],
#        [ 0.76746615,  0.39039524],
#        [-1.06630253,  0.46499305],
#        [ 0.68014383,  0.46499305],
#        [ 0.06888761, -0.47991261],
#        [-1.06630253,  1.0120437 ],
#        [ 1.11675542, -1.79780736],
#        [-1.06630253,  1.16123933],
#        [-0.71701326,  0.2411996 ],
#        [ 1.9899786 ,  1.13637339],
#        [-0.54236862, -0.38044886],
#        [-1.15362485, -0.03232572],
#        [-0.71701326, -0.30585104],
#        [-0.01843471,  0.66392056],
#        [ 0.5054992 ,  0.39039524],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.94211079,  0.71365244],
#        [-0.97898021,  0.71365244],
#        [ 0.76746615, -0.65397418],
#        [-0.80433557,  1.3353009 ],
#        [-1.50291412,  1.93208342],
#        [-0.89165789, -0.10692354],
#        [ 0.85478847, -0.25611917],
#        [-0.97898021,  0.29093148],
#        [ 0.68014383,  0.01740616],
#        [-0.71701326, -0.80316981]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 21    1
# 89    0
# 66    1
# 15    0
# 95    0
# 67    0
# 29    1
# 40    0
# 0     1
# 28    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
